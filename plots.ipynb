# %%
import pandas as pd
import geopandas as gpd

# %%
data = gpd.read_parquet("our_data/leases_with_nearest_quadrangles.parquet")
leases = gpd.read_file("raw_data/ASLD_-_State_Trust_Parcels/ASLD_-_State_Trust_Parcels.shp")

# %%
leases.plot()
# Out:
# <Axes: >

# %%
data.plot()
# Out:
# <Axes: >

# %%
# example of switching geometry
# The geometries you have are: lease_quadrangle, nearest_quadrangle, and geometry (this is the lease)
data = data.set_geometry("nearest_quadrangle")
data.plot()
# Out:
# <Axes: >

# %%
data.plot(column="acres", legend=True)
# Out:
# /opt/homebrew/anaconda3/envs/liam_science_fair/lib/python3.9/site-packages/geopandas/plotting.py:730: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):
# <Axes: >

# %%
data = data.set_geometry("geometry")
data.plot()

# lease = data.iloc[0]
# lease
# Out:
# <Axes: >

# %%
zoomedinleases = leases[leases]

# %%
xmin, ymin, xmax, ymax = -109,34,-110,35
zoomedinleases = leases.cx[xmin:xmax, ymin:ymax]
zoomedinleases.plot()
# Out:
# <Axes: >

# %%
lease = leases[leases["full_name"]=="Badger Creek Corporation"]
lease.plot()
# Out:
# <Axes: >

# %%
base = zoomedinleases.plot(color='blue')

lease.plot(ax=base, color="red");
zoomedinleases.plot(ax=base, color="orange");

# %%
leases.iloc[1]
# Out:
# OBJECTID                                                  46244
# landnum                                 1   10   28 3  1  31004
# County                                                   Apache
# parcel                                                     1004
# fundtxt                          AGRICULTURE & MECHANICAL CLLGE
# open_code                                                     0
# leased                                                        Y
# ke                                                            5
# lease_                                                   104398
# lse_code                                                      0
# lse_seq                                                       0
# effdate                                                20180930
# expdate                                                20280929
# perpetual                                                   NaN
# aus                                                         0.4
# ...
